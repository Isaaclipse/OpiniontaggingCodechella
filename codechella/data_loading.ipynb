# %%
import json
import glob
import pandas as pd
import numpy as np
import pickle
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2

# %%
filenames = glob.glob("./data/*.json")
filenames.sort()
data = []
for item in filenames:
    with open(item, 'r') as file:
        d = file.read()
    data += json.loads(d)
len(data)
# Out:
# 7079

# %%
### list of important fields
# anything after 'users' is in users
fields = ['id', 'text', 'user', 'id', 'name', 'screen_name', 'verified']

# %%
### extract data and form a dataset.  data key is its index in the originally loaded data
keys = np.arange(len(data)).tolist()
tweet_ids, texts, name, verified = [], [], [], []
for i in range(len(data)):
    tweet_ids.append(data[i]['id'])
    texts.append(data[i]['text'])
    name.append(data[i]['user']['name'])
    verified.append(data[i]['user']['name'])

# %%
data[0]
# Out:
# {'created_at': 'Thu Sep 12 18:10:20 +0000 2019',
#  'id': 1172210852415643650,
#  'id_str': '1172210852415643650',
#  'text': 'That’s what Americans do when others are in need – we help. We give. We inspire. Want to make a difference? There a… https://t.co/2mdo9GlaLl',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/2mdo9GlaLl',
#     'expanded_url': 'https://twitter.com/i/web/status/1172210852415643650',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': 1172210761583812616,
#  'in_reply_to_status_id_str': '1172210761583812616',
#  'in_reply_to_user_id': 813286,
#  'in_reply_to_user_id_str': '813286',
#  'in_reply_to_screen_name': 'BarackObama',
#  'user': {'id': 813286,
#   'id_str': '813286',
#   'name': 'Barack Obama',
#   'screen_name': 'BarackObama',
#   'location': 'Washington, DC',
#   'description': 'Dad, husband, President, citizen.',
#   'url': 'https://t.co/93Y27HEnnX',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/93Y27HEnnX',
#       'expanded_url': 'https://www.obama.org/',
#       'display_url': 'obama.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 108476855,
#   'friends_count': 612073,
#   'listed_count': 228665,
#   'created_at': 'Mon Mar 05 22:08:25 +0000 2007',
#   'favourites_count': 11,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 15678,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '77B0DC',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/822547732376207360/5g0FC8XX_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822547732376207360/5g0FC8XX_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/813286/1502508746',
#   'profile_link_color': '2574AD',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'C2E0F6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 2229,
#  'favorite_count': 11842,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
df = pd.DataFrame({'id': keys, 'tweet_id':tweet_ids,
                   'content':texts, 'author':name,
                   'verified':verified})
df.head()
# Out:
#    id             tweet_id                                            content  \
# 0   0  1172210852415643650  That’s what Americans do when others are in ne...
# 1   1  1172210761583812616  Jermaine Bell is just six years old, but when ...
# 2   2  1172210649654616067  Bahamian families and communities face a long ...
# 3   3  1171760194898059266  As we remember those we lost on 9/11, we also ...
# 4   4  1171090934257397760  Marca had a remarkable way of bringing out the...
#
#          author      verified
# 0  Barack Obama  Barack Obama
# 1  Barack Obama  Barack Obama
# 2  Barack Obama  Barack Obama
# 3  Barack Obama  Barack Obama
# 4  Barack Obama  Barack Obama

# %%
print(df.loc[178]['content'])
# Out:
# We are grieving with Parkland. But we are not powerless. Caring for our kids is our first job. And until we can hon… https://t.co/LWGSkzRapH

# %% [markdown]
# # Text cleaning and preparation

# %%
# \r and \n
df['content_parsed_1'] = df['content'].str.replace("\r", " ")
df['content_parsed_1'] = df['content_parsed_1'].str.replace("\n", " ")
df['content_parsed_1'] = df['content_parsed_1'].str.replace("    ", " ")

# %%
# " when quoting text
df['content_parsed_1'] = df['content_parsed_1'].str.replace('"', '')

# %%
# Lowercasing the text
df['content_parsed_2'] = df['content_parsed_1'].str.lower()

# %%
# punctuation sign
punctuation_signs = list("?:!.,;")
df['content_parsed_3'] = df['content_parsed_2']

for punct_sign in punctuation_signs:
    df['content_parsed_3'] = df['content_parsed_3'].str.replace(punct_sign, '')

# %%
# possessive nouns
df['content_parsed_4'] = df['content_parsed_3'].str.replace("'s", "")

# %%
# Downloading punkt and wordnet from NLTK
nltk.download('punkt')
print("------------------------------------------------------------")
nltk.download('wordnet')
# Out:
# ------------------------------------------------------------
# [nltk_data] Downloading package punkt to /Users/daisy_lab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/daisy_lab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Saving the lemmatizer into an object
wordnet_lemmatizer = WordNetLemmatizer()

# %%
# iterate through every word to lemmatize
nrows = len(df)
lemmatized_text_list = []

for row in range(0, nrows):
    
    # Create an empty list containing lemmatized words
    lemmatized_list = []
    
    # Save the text and its words into an object
    text = df.loc[row]['content_parsed_4']
    text_words = text.split(" ")

    # Iterate through every word to lemmatize
    for word in text_words:
        lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))
        
    # Join the list
    lemmatized_text = " ".join(lemmatized_list)
    
    # Append to the list containing the texts
    lemmatized_text_list.append(lemmatized_text)

# %%
df['content_parsed_5'] = lemmatized_text_list

# %%
# Downloading the stop words list
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/daisy_lab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Loading the stop words in english
stop_words = list(stopwords.words('english'))
stop_words[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# Removing all stop words
df['content_parsed_6'] = df['content_parsed_5']

for stop_word in stop_words:

    regex_stopword = r"\b" + stop_word + r"\b"
    df['content_parsed_6'] = df['content_parsed_6'].str.replace(regex_stopword, '')

# %% [markdown]
# # Label coding

# %%
category_codes = {
    'business': 0,
    'entertainment': 1,
    'politics': 2,
    'sport': 3,
    'tech': 4
}

# %% [markdown]
# # TF-IDF vectors feature

# %%
# Parameter election
ngram_range = (1,2)
min_df = 10
max_df = 1.
max_features = 300

# preparing data
X_test = df['content_parsed_6'].tolist()

# %%
tfidf = TfidfVectorizer(encoding='utf-8',
                        ngram_range=ngram_range,
                        stop_words=None,
                        lowercase=False,
                        max_df=max_df,
                        min_df=min_df,
                        max_features=max_features,
                        norm='l2',
                        sublinear_tf=True)

features_test = tfidf.fit_transform(X_test).toarray()
print(features_test.shape)
# Out:
# (7079, 300)

# %%
feature_names = tfidf.get_feature_names()
unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
bigrams = [v for v in feature_names if len(v.split(' ')) == 2]

# %%
bigrams
# Out:
# ['actonclimate https',
#  'add name',
#  'climate change',
#  'donald trump',
#  'doyourjob https',
#  'fair hear',
#  'fake news',
#  'governo bolsonaro',
#  'health care',
#  'http tco',
#  'https tco',
#  'judge garland',
#  'live president',
#  'meu deus',
#  'obama speak',
#  'president obama',
#  'senate leaders',
#  'supreme court',
#  'unite state',
#  'watch president',
#  'years ago']

# %% [markdown]
# # Prediction

# %%
svc_path = "./models/best_svc.pickle"
tfidf_path = "./models/tfidf.pickle"
with open(svc_path, 'rb') as file:
    svc = pickle.load(file)
with open(tfidf_path, 'rb') as file:
    ft_engine = pickle.load(file)

# %%
feature_test = ft_engine.transform(X_test).toarray()

# %%
def get_category_name(category_id):
    for category, id_ in category_codes.items():    
        if id_ == category_id:
            return category

# %%
### making prediction
for i in range(len(X_test)):
    prediction_svc = svc.predict(feature_test[i].reshape(1, -1))[0]
    prediction_svc_proba = svc.predict_proba(feature_test[i].reshape(1, -1))

    # Return result
    category_svc = get_category_name(prediction_svc)
    print(i, "The predicted category using the SVM model is %s." %(category_svc) )
    print("The conditional probability is: %a" %(prediction_svc_proba.max()*100))
#print(prediction_svc_proba)
# Out:
# 0 The predicted category using the SVM model is sport.
# The conditional probability is: 43.30107224431667
# 1 The predicted category using the SVM model is sport.
# The conditional probability is: 49.02145378438439
# 2 The predicted category using the SVM model is sport.
# The conditional probability is: 80.68670049152159
# 3 The predicted category using the SVM model is sport.
# The conditional probability is: 51.69305074157179
# 4 The predicted category using the SVM model is business.
# The conditional probability is: 67.77086302801982
# 5 The predicted category using the SVM model is sport.
# The conditional probability is: 77.7554766493244
# 6 The predicted category using the SVM model is sport.
# The conditional probability is: 51.08935805851218
# 7 The predicted category using the SVM model is sport.
# The conditional probability is: 37.32561397225625
# 8 The predicted category using the SVM model is sport.
# The conditional probability is: 45.7544963821579
# 9 The predicted category using the SVM model is sport.
# The conditional probability is: 72.40205434538319
# 10 The predicted category using the SVM model is sport.
# The conditional probability is: 66.8337045787923
# 11 The predicted category using the SVM model is business.
# The conditional probability is: 41.882609597853225
# 12 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 13 The predicted category using the SVM model is sport.
# The conditional probability is: 85.19705418841215
# 14 The predicted category using the SVM model is business.
# The conditional probability is: 38.998195948154816
# 15 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 16 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 17 The predicted category using the SVM model is sport.
# The conditional probability is: 56.73673468175213
# 18 The predicted category using the SVM model is sport.
# The conditional probability is: 47.571037630722046
# 19 The predicted category using the SVM model is business.
# The conditional probability is: 56.21924535980802
# 20 The predicted category using the SVM model is sport.
# The conditional probability is: 57.50568794080158
# 21 The predicted category using the SVM model is sport.
# The conditional probability is: 40.32715476828095
# 22 The predicted category using the SVM model is business.
# The conditional probability is: 42.92720918231616
# 23 The predicted category using the SVM model is sport.
# The conditional probability is: 96.58967221344477
# 24 The predicted category using the SVM model is entertainment.
# The conditional probability is: 80.72507341448184
# 25 The predicted category using the SVM model is sport.
# The conditional probability is: 93.9828558489723
# 26 The predicted category using the SVM model is sport.
# The conditional probability is: 57.57194961211582
# 27 The predicted category using the SVM model is sport.
# The conditional probability is: 99.28553524885085
# 28 The predicted category using the SVM model is sport.
# The conditional probability is: 64.03795964314418
# 29 The predicted category using the SVM model is business.
# The conditional probability is: 46.49800457702737
# 30 The predicted category using the SVM model is entertainment.
# The conditional probability is: 99.94532628961966
# 31 The predicted category using the SVM model is sport.
# The conditional probability is: 61.89934869800382
# 32 The predicted category using the SVM model is sport.
# The conditional probability is: 67.17915617584387
# 33 The predicted category using the SVM model is sport.
# The conditional probability is: 55.033499750101065
# 34 The predicted category using the SVM model is entertainment.
# The conditional probability is: 57.73960744565739
# 35 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 36 The predicted category using the SVM model is tech.
# The conditional probability is: 39.276944599903565
# 37 The predicted category using the SVM model is entertainment.
# The conditional probability is: 87.75387381546
# 38 The predicted category using the SVM model is sport.
# The conditional probability is: 96.93074420006752
# 39 The predicted category using the SVM model is business.
# The conditional probability is: 61.17254824033207
# 40 The predicted category using the SVM model is entertainment.
# The conditional probability is: 74.28784679865956
# 41 The predicted category using the SVM model is sport.
# The conditional probability is: 79.16839007559473
# 42 The predicted category using the SVM model is entertainment.
# The conditional probability is: 52.83103990943585
# 43 The predicted category using the SVM model is business.
# The conditional probability is: 50.409505163931215
# 44 The predicted category using the SVM model is sport.
# The conditional probability is: 61.67272532558364
# 45 The predicted category using the SVM model is entertainment.
# The conditional probability is: 77.0272921285208
# 46 The predicted category using the SVM model is sport.
# The conditional probability is: 87.18075372616978
# 47 The predicted category using the SVM model is sport.
# The conditional probability is: 90.41885640737486
# 48 The predicted category using the SVM model is sport.
# The conditional probability is: 53.25053008892735
# 49 The predicted category using the SVM model is sport.
# The conditional probability is: 33.37307758224395
# 50 The predicted category using the SVM model is sport.
# The conditional probability is: 51.33211593441553
# 51 The predicted category using the SVM model is entertainment.
# The conditional probability is: 83.31534484552323
# 52 The predicted category using the SVM model is entertainment.
# The conditional probability is: 34.09272520345414
# 53 The predicted category using the SVM model is entertainment.
# The conditional probability is: 59.56103912870918
# 54 The predicted category using the SVM model is business.
# The conditional probability is: 56.79186037316243
# 55 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 56 The predicted category using the SVM model is sport.
# The conditional probability is: 92.06008815441466
# 57 The predicted category using the SVM model is sport.
# The conditional probability is: 96.40528888244863
# 58 The predicted category using the SVM model is sport.
# The conditional probability is: 84.7271366185635
# 59 The predicted category using the SVM model is sport.
# The conditional probability is: 47.28020668187401
# 60 The predicted category using the SVM model is sport.
# The conditional probability is: 51.089490152932356
# 61 The predicted category using the SVM model is business.
# The conditional probability is: 60.46272247077141
# 62 The predicted category using the SVM model is sport.
# The conditional probability is: 89.94251379945926
# 63 The predicted category using the SVM model is sport.
# The conditional probability is: 99.13257192850314
# 64 The predicted category using the SVM model is business.
# The conditional probability is: 52.25359379926323
# 65 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.19794112862022
# 66 The predicted category using the SVM model is business.
# The conditional probability is: 32.830491108803436
# 67 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 68 The predicted category using the SVM model is business.
# The conditional probability is: 69.5399867107851
# 69 The predicted category using the SVM model is sport.
# The conditional probability is: 90.26754593987005
# 70 The predicted category using the SVM model is sport.
# The conditional probability is: 54.149292300321896
# 71 The predicted category using the SVM model is sport.
# The conditional probability is: 87.09851793944185
# 72 The predicted category using the SVM model is sport.
# The conditional probability is: 63.55099444507164
# 73 The predicted category using the SVM model is business.
# The conditional probability is: 29.95814543068962
# 74 The predicted category using the SVM model is sport.
# The conditional probability is: 98.29913545871014
# 75 The predicted category using the SVM model is sport.
# The conditional probability is: 68.0421812072429
# 76 The predicted category using the SVM model is tech.
# The conditional probability is: 58.44215931046638
# 77 The predicted category using the SVM model is sport.
# The conditional probability is: 95.03880173276933
# 78 The predicted category using the SVM model is sport.
# The conditional probability is: 92.75502366802412
# 79 The predicted category using the SVM model is sport.
# The conditional probability is: 57.64666092030769
# 80 The predicted category using the SVM model is sport.
# The conditional probability is: 75.47430604895919
# 81 The predicted category using the SVM model is business.
# The conditional probability is: 35.13635760799299
# 82 The predicted category using the SVM model is business.
# The conditional probability is: 65.79530732551585
# 83 The predicted category using the SVM model is business.
# The conditional probability is: 35.503613277483595
# 84 The predicted category using the SVM model is politics.
# The conditional probability is: 42.0252621655581
# 85 The predicted category using the SVM model is sport.
# The conditional probability is: 48.33105947852523
# 86 The predicted category using the SVM model is business.
# The conditional probability is: 45.553357503715326
# 87 The predicted category using the SVM model is sport.
# The conditional probability is: 81.89675933983457
# 88 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 89 The predicted category using the SVM model is sport.
# The conditional probability is: 81.37932414495077
# 90 The predicted category using the SVM model is entertainment.
# The conditional probability is: 87.75387381546
# 91 The predicted category using the SVM model is sport.
# The conditional probability is: 55.1542962244308
# 92 The predicted category using the SVM model is business.
# The conditional probability is: 66.68291494497522
# 93 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 94 The predicted category using the SVM model is sport.
# The conditional probability is: 42.18577084899607
# 95 The predicted category using the SVM model is sport.
# The conditional probability is: 83.27587863851286
# 96 The predicted category using the SVM model is sport.
# The conditional probability is: 47.20831404376209
# 97 The predicted category using the SVM model is tech.
# The conditional probability is: 78.76543115666746
# 98 The predicted category using the SVM model is entertainment.
# The conditional probability is: 60.66270135312346
# 99 The predicted category using the SVM model is sport.
# The conditional probability is: 76.03400799509667
# 100 The predicted category using the SVM model is entertainment.
# The conditional probability is: 66.25709773862994
# 101 The predicted category using the SVM model is sport.
# The conditional probability is: 42.62940527633414
# 102 The predicted category using the SVM model is sport.
# The conditional probability is: 56.94322129832579
# 103 The predicted category using the SVM model is sport.
# The conditional probability is: 39.88402053079977
# 104 The predicted category using the SVM model is sport.
# The conditional probability is: 35.93883833793553
# 105 The predicted category using the SVM model is sport.
# The conditional probability is: 71.73159651137779
# 106 The predicted category using the SVM model is sport.
# The conditional probability is: 49.29077273068689
# 107 The predicted category using the SVM model is business.
# The conditional probability is: 64.85366352469809
# 108 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 109 The predicted category using the SVM model is sport.
# The conditional probability is: 94.70906800452951
# 110 The predicted category using the SVM model is sport.
# The conditional probability is: 35.8369028394194
# 111 The predicted category using the SVM model is sport.
# The conditional probability is: 32.13482890466734
# 112 The predicted category using the SVM model is sport.
# The conditional probability is: 58.684226899876336
# 113 The predicted category using the SVM model is entertainment.
# The conditional probability is: 66.19211827195272
# 114 The predicted category using the SVM model is sport.
# The conditional probability is: 83.35897876803537
# 115 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 116 The predicted category using the SVM model is sport.
# The conditional probability is: 59.491658782118684
# 117 The predicted category using the SVM model is tech.
# The conditional probability is: 38.35801073406546
# 118 The predicted category using the SVM model is sport.
# The conditional probability is: 92.94525060882752
# 119 The predicted category using the SVM model is business.
# The conditional probability is: 63.52283831476352
# 120 The predicted category using the SVM model is tech.
# The conditional probability is: 48.134084782063816
# 121 The predicted category using the SVM model is entertainment.
# The conditional probability is: 64.12593387158601
# 122 The predicted category using the SVM model is business.
# The conditional probability is: 40.92457187587255
# 123 The predicted category using the SVM model is sport.
# The conditional probability is: 99.44379584294042
# 124 The predicted category using the SVM model is entertainment.
# The conditional probability is: 99.77536671532701
# 125 The predicted category using the SVM model is sport.
# The conditional probability is: 34.91583601762073
# 126 The predicted category using the SVM model is politics.
# The conditional probability is: 67.09602062395528
# 127 The predicted category using the SVM model is politics.
# The conditional probability is: 63.836614916112254
# 128 The predicted category using the SVM model is politics.
# The conditional probability is: 81.68114712561939
# 129 The predicted category using the SVM model is sport.
# The conditional probability is: 75.37656439501545
# 130 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 131 The predicted category using the SVM model is sport.
# The conditional probability is: 91.00469095350192
# 132 The predicted category using the SVM model is politics.
# The conditional probability is: 82.10025074791072
# 133 The predicted category using the SVM model is politics.
# The conditional probability is: 54.920641818353566
# 134 The predicted category using the SVM model is business.
# The conditional probability is: 41.6437773087515
# 135 The predicted category using the SVM model is business.
# The conditional probability is: 35.87279244722916
# 136 The predicted category using the SVM model is business.
# The conditional probability is: 96.42938996517157
# 137 The predicted category using the SVM model is politics.
# The conditional probability is: 56.636682706040276
# 138 The predicted category using the SVM model is entertainment.
# The conditional probability is: 39.07225817635481
# 139 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.38308112144198
# 140 The predicted category using the SVM model is entertainment.
# The conditional probability is: 95.12194298894853
# 141 The predicted category using the SVM model is entertainment.
# The conditional probability is: 67.43057523074803
# 142 The predicted category using the SVM model is sport.
# The conditional probability is: 51.988368041698216
# 143 The predicted category using the SVM model is politics.
# The conditional probability is: 66.24940178571266
# 144 The predicted category using the SVM model is politics.
# The conditional probability is: 87.48730604318189
# 145 The predicted category using the SVM model is sport.
# The conditional probability is: 49.453461614798066
# 146 The predicted category using the SVM model is business.
# The conditional probability is: 46.09160928312371
# 147 The predicted category using the SVM model is business.
# The conditional probability is: 37.54038902385069
# 148 The predicted category using the SVM model is sport.
# The conditional probability is: 51.983403203513866
# 149 The predicted category using the SVM model is sport.
# The conditional probability is: 99.56204546081207
# 150 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 151 The predicted category using the SVM model is tech.
# The conditional probability is: 43.704846592229345
# 152 The predicted category using the SVM model is entertainment.
# The conditional probability is: 97.55597918143671
# 153 The predicted category using the SVM model is business.
# The conditional probability is: 46.1311906329603
# 154 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 155 The predicted category using the SVM model is sport.
# The conditional probability is: 52.09447182635877
# 156 The predicted category using the SVM model is sport.
# The conditional probability is: 53.5763788312743
# 157 The predicted category using the SVM model is sport.
# The conditional probability is: 59.008893803399666
# 158 The predicted category using the SVM model is business.
# The conditional probability is: 56.79186037316243
# 159 The predicted category using the SVM model is entertainment.
# The conditional probability is: 90.5319518710057
# 160 The predicted category using the SVM model is business.
# The conditional probability is: 64.76661488196712
# 161 The predicted category using the SVM model is business.
# The conditional probability is: 44.621815928480316
# 162 The predicted category using the SVM model is entertainment.
# The conditional probability is: 72.94604002973944
# 163 The predicted category using the SVM model is business.
# The conditional probability is: 35.33479085195805
# 164 The predicted category using the SVM model is tech.
# The conditional probability is: 69.57984943562602
# 165 The predicted category using the SVM model is sport.
# The conditional probability is: 45.98276782557641
# 166 The predicted category using the SVM model is sport.
# The conditional probability is: 98.73290962053987
# 167 The predicted category using the SVM model is sport.
# The conditional probability is: 37.883094867394156
# 168 The predicted category using the SVM model is sport.
# The conditional probability is: 50.67637782875328
# 169 The predicted category using the SVM model is tech.
# The conditional probability is: 71.04558169621365
# 170 The predicted category using the SVM model is sport.
# The conditional probability is: 91.57502606492912
# 171 The predicted category using the SVM model is sport.
# The conditional probability is: 90.07207211027739
# 172 The predicted category using the SVM model is sport.
# The conditional probability is: 63.87759430882801
# 173 The predicted category using the SVM model is entertainment.
# The conditional probability is: 99.97629199649182
# 174 The predicted category using the SVM model is sport.
# The conditional probability is: 58.53834395161846
# 175 The predicted category using the SVM model is sport.
# The conditional probability is: 64.07574772906682
# 176 The predicted category using the SVM model is sport.
# The conditional probability is: 39.07433303365275
# 177 The predicted category using the SVM model is sport.
# The conditional probability is: 31.151141948690587
# 178 The predicted category using the SVM model is sport.
# The conditional probability is: 42.21396294122832
# 179 The predicted category using the SVM model is sport.
# The conditional probability is: 59.28426841667839
# 180 The predicted category using the SVM model is sport.
# The conditional probability is: 82.06389072310692
# 181 The predicted category using the SVM model is tech.
# The conditional probability is: 50.374037296413945
# 182 The predicted category using the SVM model is sport.
# The conditional probability is: 51.46805521049224
# 183 The predicted category using the SVM model is sport.
# The conditional probability is: 92.61847801498662
# 184 The predicted category using the SVM model is sport.
# The conditional probability is: 50.86795198299604
# 185 The predicted category using the SVM model is business.
# The conditional probability is: 39.05951407881577
# 186 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 187 The predicted category using the SVM model is sport.
# The conditional probability is: 97.78692867282791
# 188 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 189 The predicted category using the SVM model is business.
# The conditional probability is: 27.88712850048059
# 190 The predicted category using the SVM model is entertainment.
# The conditional probability is: 71.31253250273839
# 191 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 192 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 193 The predicted category using the SVM model is politics.
# The conditional probability is: 62.46826632640678
# 194 The predicted category using the SVM model is politics.
# The conditional probability is: 47.85133499004566
# 195 The predicted category using the SVM model is business.
# The conditional probability is: 55.31996114574022
# 196 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.28844057946043
# 197 The predicted category using the SVM model is sport.
# The conditional probability is: 43.576374734569626
# 198 The predicted category using the SVM model is business.
# The conditional probability is: 57.45907022696446
# 199 The predicted category using the SVM model is sport.
# The conditional probability is: 69.62081693996578
# 200 The predicted category using the SVM model is sport.
# The conditional probability is: 72.38557893521909
# 201 The predicted category using the SVM model is sport.
# The conditional probability is: 32.79879159401187
# 202 The predicted category using the SVM model is business.
# The conditional probability is: 52.57143232332203
# 203 The predicted category using the SVM model is sport.
# The conditional probability is: 53.41172600123157
# 204 The predicted category using the SVM model is sport.
# The conditional probability is: 96.80408559330658
# 205 The predicted category using the SVM model is business.
# The conditional probability is: 43.35811559188482
# 206 The predicted category using the SVM model is sport.
# The conditional probability is: 44.363299907950434
# 207 The predicted category using the SVM model is sport.
# The conditional probability is: 65.86181561575563
# 208 The predicted category using the SVM model is tech.
# The conditional probability is: 37.3066189596868
# 209 The predicted category using the SVM model is sport.
# The conditional probability is: 34.47572289976566
# 210 The predicted category using the SVM model is business.
# The conditional probability is: 36.623970139742916
# 211 The predicted category using the SVM model is sport.
# The conditional probability is: 33.85104647147426
# 212 The predicted category using the SVM model is business.
# The conditional probability is: 31.25386369142723
# 213 The predicted category using the SVM model is business.
# The conditional probability is: 37.88444029663346
# 214 The predicted category using the SVM model is entertainment.
# The conditional probability is: 45.76512005998457
# 215 The predicted category using the SVM model is sport.
# The conditional probability is: 65.86181561575563
# 216 The predicted category using the SVM model is sport.
# The conditional probability is: 52.13118384925563
# 217 The predicted category using the SVM model is tech.
# The conditional probability is: 49.57242720164525
# 218 The predicted category using the SVM model is sport.
# The conditional probability is: 52.43121719648938
# 219 The predicted category using the SVM model is sport.
# The conditional probability is: 69.08929492320708
# 220 The predicted category using the SVM model is business.
# The conditional probability is: 46.1311906329603
# 221 The predicted category using the SVM model is entertainment.
# The conditional probability is: 71.31253250273839
# 222 The predicted category using the SVM model is entertainment.
# The conditional probability is: 86.20272675579064
# 223 The predicted category using the SVM model is business.
# The conditional probability is: 51.751755703428195
# 224 The predicted category using the SVM model is sport.
# The conditional probability is: 34.325733902715605
# 225 The predicted category using the SVM model is entertainment.
# The conditional probability is: 89.5546209793604
# 226 The predicted category using the SVM model is politics.
# The conditional probability is: 41.216760446696384
# 227 The predicted category using the SVM model is sport.
# The conditional probability is: 38.80796679470918
# 228 The predicted category using the SVM model is entertainment.
# The conditional probability is: 71.03065867366276
# 229 The predicted category using the SVM model is sport.
# The conditional probability is: 61.882771780190794
# 230 The predicted category using the SVM model is sport.
# The conditional probability is: 51.405007501564015
# 231 The predicted category using the SVM model is entertainment.
# The conditional probability is: 82.55341774347714
# 232 The predicted category using the SVM model is sport.
# The conditional probability is: 65.63697063157116
# 233 The predicted category using the SVM model is sport.
# The conditional probability is: 49.931288075441266
# 234 The predicted category using the SVM model is business.
# The conditional probability is: 30.154494560779522
# 235 The predicted category using the SVM model is sport.
# The conditional probability is: 38.49270188176593
# 236 The predicted category using the SVM model is entertainment.
# The conditional probability is: 87.95754712767524
# 237 The predicted category using the SVM model is entertainment.
# The conditional probability is: 68.30683143506322
# 238 The predicted category using the SVM model is business.
# The conditional probability is: 38.72423377302358
# 239 The predicted category using the SVM model is sport.
# The conditional probability is: 80.41095452293901
# 240 The predicted category using the SVM model is business.
# The conditional probability is: 47.2593488215317
# 241 The predicted category using the SVM model is business.
# The conditional probability is: 54.62242481187095
# 242 The predicted category using the SVM model is business.
# The conditional probability is: 36.47376252166831
# 243 The predicted category using the SVM model is sport.
# The conditional probability is: 57.01380845880841
# 244 The predicted category using the SVM model is business.
# The conditional probability is: 72.65673680858929
# 245 The predicted category using the SVM model is sport.
# The conditional probability is: 54.87030065342798
# 246 The predicted category using the SVM model is business.
# The conditional probability is: 60.98567965670377
# 247 The predicted category using the SVM model is entertainment.
# The conditional probability is: 74.66508901860924
# 248 The predicted category using the SVM model is sport.
# The conditional probability is: 84.22443960360309
# 249 The predicted category using the SVM model is sport.
# The conditional probability is: 65.14370059388779
# 250 The predicted category using the SVM model is tech.
# The conditional probability is: 38.139186911042266
# 251 The predicted category using the SVM model is sport.
# The conditional probability is: 66.5997807042905
# 252 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 253 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 254 The predicted category using the SVM model is business.
# The conditional probability is: 42.888608384282044
# 255 The predicted category using the SVM model is sport.
# The conditional probability is: 45.20646090316999
# 256 The predicted category using the SVM model is sport.
# The conditional probability is: 80.240351091322
# 257 The predicted category using the SVM model is business.
# The conditional probability is: 36.90141326498044
# 258 The predicted category using the SVM model is sport.
# The conditional probability is: 64.77127538616779
# 259 The predicted category using the SVM model is sport.
# The conditional probability is: 98.17152222869066
# 260 The predicted category using the SVM model is sport.
# The conditional probability is: 36.142698118441395
# 261 The predicted category using the SVM model is sport.
# The conditional probability is: 85.33020805549035
# 262 The predicted category using the SVM model is business.
# The conditional probability is: 44.167752322843526
# 263 The predicted category using the SVM model is sport.
# The conditional probability is: 70.68164509335358
# 264 The predicted category using the SVM model is entertainment.
# The conditional probability is: 86.7819396450934
# 265 The predicted category using the SVM model is business.
# The conditional probability is: 69.67915267768923
# 266 The predicted category using the SVM model is business.
# The conditional probability is: 44.3913647435139
# 267 The predicted category using the SVM model is sport.
# The conditional probability is: 38.61575770886793
# 268 The predicted category using the SVM model is sport.
# The conditional probability is: 33.31444009944578
# 269 The predicted category using the SVM model is politics.
# The conditional probability is: 41.68176939710001
# 270 The predicted category using the SVM model is sport.
# The conditional probability is: 98.80668672472048
# 271 The predicted category using the SVM model is sport.
# The conditional probability is: 39.299992490490645
# 272 The predicted category using the SVM model is business.
# The conditional probability is: 36.5170768165396
# 273 The predicted category using the SVM model is business.
# The conditional probability is: 63.06198703213573
# 274 The predicted category using the SVM model is sport.
# The conditional probability is: 74.13101098940558
# 275 The predicted category using the SVM model is sport.
# The conditional probability is: 37.981722546906035
# 276 The predicted category using the SVM model is sport.
# The conditional probability is: 98.80668672472048
# 277 The predicted category using the SVM model is sport.
# The conditional probability is: 35.29621055885993
# 278 The predicted category using the SVM model is entertainment.
# The conditional probability is: 49.66653613747636
# 279 The predicted category using the SVM model is sport.
# The conditional probability is: 31.74715933953612
# 280 The predicted category using the SVM model is sport.
# The conditional probability is: 34.83173392189457
# 281 The predicted category using the SVM model is entertainment.
# The conditional probability is: 67.6603708720228
# 282 The predicted category using the SVM model is entertainment.
# The conditional probability is: 68.44133958013826
# 283 The predicted category using the SVM model is sport.
# The conditional probability is: 92.44612615727647
# 284 The predicted category using the SVM model is sport.
# The conditional probability is: 81.10823241662082
# 285 The predicted category using the SVM model is sport.
# The conditional probability is: 55.3025264229961
# 286 The predicted category using the SVM model is business.
# The conditional probability is: 37.217149421289015
# 287 The predicted category using the SVM model is business.
# The conditional probability is: 37.44998370372111
# 288 The predicted category using the SVM model is sport.
# The conditional probability is: 49.55818566005512
# 289 The predicted category using the SVM model is sport.
# The conditional probability is: 52.426997934055706
# 290 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 291 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 292 The predicted category using the SVM model is sport.
# The conditional probability is: 33.99155246729123
# 293 The predicted category using the SVM model is business.
# The conditional probability is: 43.65400423889486
# 294 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 295 The predicted category using the SVM model is business.
# The conditional probability is: 49.3042660890238
# 296 The predicted category using the SVM model is sport.
# The conditional probability is: 76.24248139370363
# 297 The predicted category using the SVM model is sport.
# The conditional probability is: 49.55818566005512
# 298 The predicted category using the SVM model is sport.
# The conditional probability is: 33.89477954285307
# 299 The predicted category using the SVM model is business.
# The conditional probability is: 62.75727031447546
# 300 The predicted category using the SVM model is politics.
# The conditional probability is: 58.180440221135086
# 301 The predicted category using the SVM model is business.
# The conditional probability is: 43.65400423889486
# 302 The predicted category using the SVM model is sport.
# The conditional probability is: 66.50475638953728
# 303 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.33661988606814
# 304 The predicted category using the SVM model is politics.
# The conditional probability is: 38.841120389872216
# 305 The predicted category using the SVM model is business.
# The conditional probability is: 76.86339038827658
# 306 The predicted category using the SVM model is sport.
# The conditional probability is: 43.76282775370898
# 307 The predicted category using the SVM model is politics.
# The conditional probability is: 42.66707787557686
# 308 The predicted category using the SVM model is business.
# The conditional probability is: 54.62242481187095
# 309 The predicted category using the SVM model is business.
# The conditional probability is: 38.28171895632122
# 310 The predicted category using the SVM model is politics.
# The conditional probability is: 43.207451103649525
# 311 The predicted category using the SVM model is politics.
# The conditional probability is: 42.09595651243154
# 312 The predicted category using the SVM model is sport.
# The conditional probability is: 85.9344344164098
# 313 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 314 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 315 The predicted category using the SVM model is business.
# The conditional probability is: 29.95814543068962
# 316 The predicted category using the SVM model is entertainment.
# The conditional probability is: 49.65205437735135
# 317 The predicted category using the SVM model is business.
# The conditional probability is: 69.48601600158906
# 318 The predicted category using the SVM model is business.
# The conditional probability is: 51.14025300651149
# 319 The predicted category using the SVM model is business.
# The conditional probability is: 87.65654467794344
# 320 The predicted category using the SVM model is business.
# The conditional probability is: 85.09866855561174
# 321 The predicted category using the SVM model is business.
# The conditional probability is: 39.21382072779035
# 322 The predicted category using the SVM model is tech.
# The conditional probability is: 66.29454129777052
# 323 The predicted category using the SVM model is sport.
# The conditional probability is: 52.13118384925563
# 324 The predicted category using the SVM model is business.
# The conditional probability is: 39.28637928680009
# 325 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.33661988606814
# 326 The predicted category using the SVM model is business.
# The conditional probability is: 43.65400423889486
# 327 The predicted category using the SVM model is sport.
# The conditional probability is: 52.989461552255
# 328 The predicted category using the SVM model is business.
# The conditional probability is: 47.16290710208929
# 329 The predicted category using the SVM model is sport.
# The conditional probability is: 65.61380322377967
# 330 The predicted category using the SVM model is business.
# The conditional probability is: 58.4333774534737
# 331 The predicted category using the SVM model is sport.
# The conditional probability is: 76.90360091702173
# 332 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 333 The predicted category using the SVM model is business.
# The conditional probability is: 64.23875109134869
# 334 The predicted category using the SVM model is sport.
# The conditional probability is: 40.883847015979
# 335 The predicted category using the SVM model is business.
# The conditional probability is: 67.59187403420958
# 336 The predicted category using the SVM model is politics.
# The conditional probability is: 47.430489825203345
# 337 The predicted category using the SVM model is politics.
# The conditional probability is: 46.15353139021374
# 338 The predicted category using the SVM model is business.
# The conditional probability is: 42.35262732307231
# 339 The predicted category using the SVM model is business.
# The conditional probability is: 43.46319940744302
# 340 The predicted category using the SVM model is business.
# The conditional probability is: 89.06660554608126
# 341 The predicted category using the SVM model is sport.
# The conditional probability is: 98.53308201247553
# 342 The predicted category using the SVM model is sport.
# The conditional probability is: 33.46802666600113
# 343 The predicted category using the SVM model is sport.
# The conditional probability is: 44.45501278059115
# 344 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 345 The predicted category using the SVM model is business.
# The conditional probability is: 43.8442487316205
# 346 The predicted category using the SVM model is sport.
# The conditional probability is: 67.19983342852119
# 347 The predicted category using the SVM model is sport.
# The conditional probability is: 98.80668672472048
# 348 The predicted category using the SVM model is business.
# The conditional probability is: 33.450095794140154
# 349 The predicted category using the SVM model is sport.
# The conditional probability is: 46.96804612830021
# 350 The predicted category using the SVM model is business.
# The conditional probability is: 38.06834628865056
# 351 The predicted category using the SVM model is sport.
# The conditional probability is: 67.19983342852119
# 352 The predicted category using the SVM model is politics.
# The conditional probability is: 48.63755568497972
# 353 The predicted category using the SVM model is business.
# The conditional probability is: 87.56980291332226
# 354 The predicted category using the SVM model is entertainment.
# The conditional probability is: 82.04339207175644
# 355 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 356 The predicted category using the SVM model is entertainment.
# The conditional probability is: 72.94655182339989
# 357 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 358 The predicted category using the SVM model is politics.
# The conditional probability is: 61.52274066825994
# 359 The predicted category using the SVM model is sport.
# The conditional probability is: 31.196570636223825
# 360 The predicted category using the SVM model is sport.
# The conditional probability is: 53.063960232504556
# 361 The predicted category using the SVM model is business.
# The conditional probability is: 43.65400423889486
# 362 The predicted category using the SVM model is sport.
# The conditional probability is: 56.80348675243844
# 363 The predicted category using the SVM model is politics.
# The conditional probability is: 41.66884251255192
# 364 The predicted category using the SVM model is business.
# The conditional probability is: 31.17990587611601
# 365 The predicted category using the SVM model is sport.
# The conditional probability is: 34.876963664694856
# 366 The predicted category using the SVM model is sport.
# The conditional probability is: 93.20474367697477
# 367 The predicted category using the SVM model is business.
# The conditional probability is: 34.715512200002465
# 368 The predicted category using the SVM model is entertainment.
# The conditional probability is: 76.3427267921374
# 369 The predicted category using the SVM model is business.
# The conditional probability is: 54.62242481187095
# 370 The predicted category using the SVM model is sport.
# The conditional probability is: 31.689676098951615
# 371 The predicted category using the SVM model is sport.
# The conditional probability is: 89.6027525529923
# 372 The predicted category using the SVM model is business.
# The conditional probability is: 58.91820495519301
# 373 The predicted category using the SVM model is sport.
# The conditional probability is: 83.55609782441331
# 374 The predicted category using the SVM model is business.
# The conditional probability is: 40.319503006173726
# 375 The predicted category using the SVM model is politics.
# The conditional probability is: 76.25684534307747
# 376 The predicted category using the SVM model is sport.
# The conditional probability is: 48.47104210301841
# 377 The predicted category using the SVM model is entertainment.
# The conditional probability is: 70.33661988606814
# 378 The predicted category using the SVM model is business.
# The conditional probability is: 49.3042660890238
# 379 The predicted category using the SVM model is sport.
# The conditional probability is: 33.05953856872271
# 380 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 381 The predicted category using the SVM model is business.
# The conditional probability is: 77.99311042104517
# 382 The predicted category using the SVM model is sport.
# The conditional probability is: 72.78622900950849
# 383 The predicted category using the SVM model is entertainment.
# The conditional probability is: 49.65205437735135
# 384 The predicted category using the SVM model is business.
# The conditional probability is: 45.877038348702584
# 385 The predicted category using the SVM model is business.
# The conditional probability is: 48.09238129940238
# 386 The predicted category using the SVM model is sport.
# The conditional probability is: 50.34141402960285
# 387 The predicted category using the SVM model is business.
# The conditional probability is: 49.552281683545154
# 388 The predicted category using the SVM model is entertainment.
# The conditional probability is: 79.7654543997606
# 389 The predicted category using the SVM model is business.
# The conditional probability is: 33.78384886395961
# 390 The predicted category using the SVM model is sport.
# The conditional probability is: 31.847684878993025
# 391 The predicted category using the SVM model is business.
# The conditional probability is: 39.94706858248486
# 392 The predicted category using the SVM model is business.
# The conditional probability is: 37.217149421289015
# 393 The predicted category using the SVM model is politics.
# The conditional probability is: 40.48146406981439
# 394 The predicted category using the SVM model is sport.
# The conditional probability is: 50.061156342863164
# 395 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 396 The predicted category using the SVM model is business.
# The conditional probability is: 37.294910608249346
# 397 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 398 The predicted category using the SVM model is sport.
# The conditional probability is: 72.30947112858426
# 399 The predicted category using the SVM model is politics.
# The conditional probability is: 36.16952677715593
# 400 The predicted category using the SVM model is politics.
# The conditional probability is: 54.25209884439833
# 401 The predicted category using the SVM model is business.
# The conditional probability is: 34.434022234543846
# 402 The predicted category using the SVM model is business.
# The conditional probability is: 56.567990696554126
# 403 The predicted category using the SVM model is business.
# The conditional probability is: 25.87361796329638
# 404 The predicted category using the SVM model is business.
# The conditional probability is: 60.8095512867049
# 405 The predicted category using the SVM model is business.
# The conditional probability is: 54.62242481187095
# 406 The predicted category using the SVM model is business.
# The conditional probability is: 80.18251477959808
# 407 The predicted category using the SVM model is business.
# The conditional probability is: 61.040748448031636
# 408 The predicted category using the SVM model is sport.
# The conditional probability is: 68.09703062072766
# 409 The predicted category using the SVM model is business.
# The conditional probability is: 39.16525900594591
# 410 The predicted category using the SVM model is sport.
# The conditional probability is: 55.659007301515885
# 411 The predicted category using the SVM model is business.
# The conditional probability is: 85.09866855561174
# 412 The predicted category using the SVM model is politics.
# The conditional probability is: 55.47474809202092
# 413 The predicted category using the SVM model is business.
# The conditional probability is: 61.040748448031636
# 414 The predicted category using the SVM model is sport.
# The conditional probability is: 97.43213764407338
# 415 The predicted category using the SVM model is politics.
# The conditional probability is: 54.437806053311824
# 416 The predicted category using the SVM model is business.
# The conditional probability is: 43.65400423889486
# 417 The predicted category using the SVM model is politics.
# The conditional probability is: 64.72518253134977
# 418 The predicted category using the SVM model is sport.
# The conditional probability is: 44.177628370233236
# 419 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 420 The predicted category using the SVM model is sport.
# The conditional probability is: 99.20908906851264
# 421 The predicted category using the SVM model is entertainment.
# The conditional probability is: 99.57848571398378
# 422 The predicted category using the SVM model is politics.
# The conditional probability is: 86.76273087038253
# 423 The predicted category using the SVM model is politics.
# The conditional probability is: 51.87511551972557
# 424 The predicted category using the SVM model is business.
# The conditional probability is: 37.27040959525181
# 425 The predicted category using the SVM model is business.
# The conditional probability is: 58.203331590329995
# 426 The predicted category using the SVM model is sport.
# The conditional probability is: 35.05658566894099
# 427 The predicted category using the SVM model is business.
# The conditional probability is: 39.5193277630232
# 428 The predicted category using the SVM model is sport.
# The conditional probability is: 69.94983676148443
# 429 The predicted category using the SVM model is sport.
# The conditional probability is: 74.59830395356116
# 430 The predicted category using the SVM model is entertainment.
# The conditional probability is: 82.91784394451635
# 431 The predicted category using the SVM model is sport.
# The conditional probability is: 60.64390516595801
# 432 The predicted category using the SVM model is business.
# The conditional probability is: 47.05130233643662
# 433 The predicted category using the SVM model is business.
# The conditional probability is: 48.5982878169891
# 434 The predicted category using the SVM model is sport.
# The conditional probability is: 83.26905022383959
# 435 The predicted category using the SVM model is business.
# The conditional probability is: 38.17646123711573
# 436 The predicted category using the SVM model is business.
# The conditional probability is: 39.18487382311997
# 437 The predicted category using the SVM model is entertainment.
# The conditional probability is: 40.24637037113437
# 438 The predicted category using the SVM model is entertainment.
# The conditional probability is: 69.25172058738646
# 439 The predicted category using the SVM model is business.
# The conditional probability is: 29.509245141458525
# 440 The predicted category using the SVM model is sport.
# The conditional probability is: 93.88555675292709
# ...
# The conditional probability is: 61.85362782189047
# 6934 The predicted category using the SVM model is sport.
# The conditional probability is: 65.999702765743
# 6935 The predicted category using the SVM model is sport.
# The conditional probability is: 52.71004495917233
# 6936 The predicted category using the SVM model is politics.
# The conditional probability is: 61.812416548298934
# 6937 The predicted category using the SVM model is business.
# The conditional probability is: 46.13418224814994
# 6938 The predicted category using the SVM model is sport.
# The conditional probability is: 53.9738767990701
# 6939 The predicted category using the SVM model is entertainment.
# The conditional probability is: 85.07210537758615
# 6940 The predicted category using the SVM model is sport.
# The conditional probability is: 47.74317981333307
# 6941 The predicted category using the SVM model is sport.
# The conditional probability is: 41.01649794185088
# 6942 The predicted category using the SVM model is business.
# The conditional probability is: 44.577652983027214
# 6943 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6944 The predicted category using the SVM model is sport.
# The conditional probability is: 68.6099023065008
# 6945 The predicted category using the SVM model is business.
# The conditional probability is: 27.602226094528454
# 6946 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6947 The predicted category using the SVM model is politics.
# The conditional probability is: 68.09377342007538
# 6948 The predicted category using the SVM model is entertainment.
# The conditional probability is: 89.73296572408648
# 6949 The predicted category using the SVM model is politics.
# The conditional probability is: 50.15686623954502
# 6950 The predicted category using the SVM model is sport.
# The conditional probability is: 78.20056335055116
# 6951 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6952 The predicted category using the SVM model is entertainment.
# The conditional probability is: 85.07210537758615
# 6953 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6954 The predicted category using the SVM model is entertainment.
# The conditional probability is: 78.6312449613635
# 6955 The predicted category using the SVM model is entertainment.
# The conditional probability is: 49.21714853508611
# 6956 The predicted category using the SVM model is business.
# The conditional probability is: 50.8089035952884
# 6957 The predicted category using the SVM model is business.
# The conditional probability is: 90.70567880807697
# 6958 The predicted category using the SVM model is business.
# The conditional probability is: 58.75017576493169
# 6959 The predicted category using the SVM model is business.
# The conditional probability is: 48.01444312207546
# 6960 The predicted category using the SVM model is business.
# The conditional probability is: 99.59315057176474
# 6961 The predicted category using the SVM model is business.
# The conditional probability is: 31.481638636009546
# 6962 The predicted category using the SVM model is entertainment.
# The conditional probability is: 90.29992486006503
# 6963 The predicted category using the SVM model is business.
# The conditional probability is: 59.04354645815584
# 6964 The predicted category using the SVM model is business.
# The conditional probability is: 47.65563204843236
# 6965 The predicted category using the SVM model is sport.
# The conditional probability is: 44.73973171277255
# 6966 The predicted category using the SVM model is sport.
# The conditional probability is: 77.64419874965132
# 6967 The predicted category using the SVM model is sport.
# The conditional probability is: 38.472894301719954
# 6968 The predicted category using the SVM model is sport.
# The conditional probability is: 53.338443096831035
# 6969 The predicted category using the SVM model is sport.
# The conditional probability is: 58.11268065228341
# 6970 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6971 The predicted category using the SVM model is entertainment.
# The conditional probability is: 81.89453232145635
# 6972 The predicted category using the SVM model is entertainment.
# The conditional probability is: 66.42983808576832
# 6973 The predicted category using the SVM model is politics.
# The conditional probability is: 97.24973465112805
# 6974 The predicted category using the SVM model is sport.
# The conditional probability is: 99.52587517134488
# 6975 The predicted category using the SVM model is sport.
# The conditional probability is: 87.9982613898896
# 6976 The predicted category using the SVM model is business.
# The conditional probability is: 30.475856314587897
# 6977 The predicted category using the SVM model is politics.
# The conditional probability is: 42.96150555540743
# 6978 The predicted category using the SVM model is tech.
# The conditional probability is: 45.22890824468219
# 6979 The predicted category using the SVM model is sport.
# The conditional probability is: 59.19685956716908
# 6980 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6981 The predicted category using the SVM model is entertainment.
# The conditional probability is: 97.89812103193056
# 6982 The predicted category using the SVM model is sport.
# The conditional probability is: 69.2105993674458
# 6983 The predicted category using the SVM model is sport.
# The conditional probability is: 55.635431436194004
# 6984 The predicted category using the SVM model is politics.
# The conditional probability is: 60.82682592920392
# 6985 The predicted category using the SVM model is sport.
# The conditional probability is: 62.90340538923509
# 6986 The predicted category using the SVM model is sport.
# The conditional probability is: 92.75502366802412
# 6987 The predicted category using the SVM model is business.
# The conditional probability is: 37.50062561405634
# 6988 The predicted category using the SVM model is business.
# The conditional probability is: 51.7035053230355
# 6989 The predicted category using the SVM model is sport.
# The conditional probability is: 36.27547150343314
# 6990 The predicted category using the SVM model is business.
# The conditional probability is: 46.450445184777706
# 6991 The predicted category using the SVM model is entertainment.
# The conditional probability is: 99.43847528322208
# 6992 The predicted category using the SVM model is sport.
# The conditional probability is: 47.942407258997285
# 6993 The predicted category using the SVM model is business.
# The conditional probability is: 41.56001125961078
# 6994 The predicted category using the SVM model is business.
# The conditional probability is: 36.62385204165032
# 6995 The predicted category using the SVM model is tech.
# The conditional probability is: 63.669893009600266
# 6996 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6997 The predicted category using the SVM model is business.
# The conditional probability is: 33.75624296207919
# 6998 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 6999 The predicted category using the SVM model is sport.
# The conditional probability is: 39.86352005072676
# 7000 The predicted category using the SVM model is entertainment.
# The conditional probability is: 62.85615732634962
# 7001 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7002 The predicted category using the SVM model is sport.
# The conditional probability is: 37.903287991688416
# 7003 The predicted category using the SVM model is politics.
# The conditional probability is: 70.3073191355742
# 7004 The predicted category using the SVM model is business.
# The conditional probability is: 46.55846685641076
# 7005 The predicted category using the SVM model is sport.
# The conditional probability is: 31.00044922578644
# 7006 The predicted category using the SVM model is business.
# The conditional probability is: 45.78839714984826
# 7007 The predicted category using the SVM model is sport.
# The conditional probability is: 86.73912135106877
# 7008 The predicted category using the SVM model is business.
# The conditional probability is: 37.10990644810075
# 7009 The predicted category using the SVM model is sport.
# The conditional probability is: 38.346745735935386
# 7010 The predicted category using the SVM model is sport.
# The conditional probability is: 79.57214855190887
# 7011 The predicted category using the SVM model is sport.
# The conditional probability is: 29.553597062610866
# 7012 The predicted category using the SVM model is sport.
# The conditional probability is: 92.75502366802412
# 7013 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7014 The predicted category using the SVM model is sport.
# The conditional probability is: 89.61011428671509
# 7015 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7016 The predicted category using the SVM model is entertainment.
# The conditional probability is: 59.709816029594265
# 7017 The predicted category using the SVM model is business.
# The conditional probability is: 46.49800457702737
# 7018 The predicted category using the SVM model is sport.
# The conditional probability is: 45.976588779610324
# 7019 The predicted category using the SVM model is business.
# The conditional probability is: 66.61065735436465
# 7020 The predicted category using the SVM model is sport.
# The conditional probability is: 61.14837326350258
# 7021 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7022 The predicted category using the SVM model is politics.
# The conditional probability is: 51.73557767826963
# 7023 The predicted category using the SVM model is sport.
# The conditional probability is: 43.449956372949835
# 7024 The predicted category using the SVM model is sport.
# The conditional probability is: 57.08280549212744
# 7025 The predicted category using the SVM model is politics.
# The conditional probability is: 55.27817957031188
# 7026 The predicted category using the SVM model is politics.
# The conditional probability is: 56.75410057784408
# 7027 The predicted category using the SVM model is entertainment.
# The conditional probability is: 59.10108882236579
# 7028 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7029 The predicted category using the SVM model is business.
# The conditional probability is: 47.01604237877374
# 7030 The predicted category using the SVM model is business.
# The conditional probability is: 43.732001754035835
# 7031 The predicted category using the SVM model is sport.
# The conditional probability is: 44.20523388795282
# 7032 The predicted category using the SVM model is sport.
# The conditional probability is: 48.918666195534335
# 7033 The predicted category using the SVM model is sport.
# The conditional probability is: 50.085105791763866
# 7034 The predicted category using the SVM model is business.
# The conditional probability is: 37.10148813414599
# 7035 The predicted category using the SVM model is business.
# The conditional probability is: 86.98928033937267
# 7036 The predicted category using the SVM model is business.
# The conditional probability is: 34.424298384367205
# 7037 The predicted category using the SVM model is sport.
# The conditional probability is: 39.28305087722438
# 7038 The predicted category using the SVM model is sport.
# The conditional probability is: 42.62757318321137
# 7039 The predicted category using the SVM model is sport.
# The conditional probability is: 92.75502366802412
# 7040 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7041 The predicted category using the SVM model is sport.
# The conditional probability is: 62.17961001789681
# 7042 The predicted category using the SVM model is business.
# The conditional probability is: 54.62242481187095
# 7043 The predicted category using the SVM model is tech.
# The conditional probability is: 45.40265170788964
# 7044 The predicted category using the SVM model is business.
# The conditional probability is: 38.814861805395154
# 7045 The predicted category using the SVM model is sport.
# The conditional probability is: 48.055129776977964
# 7046 The predicted category using the SVM model is tech.
# The conditional probability is: 45.40265170788964
# 7047 The predicted category using the SVM model is tech.
# The conditional probability is: 48.640244750288204
# 7048 The predicted category using the SVM model is business.
# The conditional probability is: 52.621325607865366
# 7049 The predicted category using the SVM model is sport.
# The conditional probability is: 80.82425444504617
# 7050 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7051 The predicted category using the SVM model is business.
# The conditional probability is: 40.25715874202632
# 7052 The predicted category using the SVM model is sport.
# The conditional probability is: 80.52272270196464
# 7053 The predicted category using the SVM model is business.
# The conditional probability is: 87.50803291558954
# 7054 The predicted category using the SVM model is business.
# The conditional probability is: 80.67779230627082
# 7055 The predicted category using the SVM model is business.
# The conditional probability is: 77.21125157463185
# 7056 The predicted category using the SVM model is business.
# The conditional probability is: 96.45515677030278
# 7057 The predicted category using the SVM model is business.
# The conditional probability is: 61.063327518357326
# 7058 The predicted category using the SVM model is business.
# The conditional probability is: 62.909675132749356
# 7059 The predicted category using the SVM model is sport.
# The conditional probability is: 50.152878696580075
# 7060 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7061 The predicted category using the SVM model is sport.
# The conditional probability is: 51.03428451846758
# 7062 The predicted category using the SVM model is sport.
# The conditional probability is: 39.1665121634946
# 7063 The predicted category using the SVM model is entertainment.
# The conditional probability is: 98.9604770939842
# 7064 The predicted category using the SVM model is sport.
# The conditional probability is: 50.62974340463221
# 7065 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7066 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7067 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7068 The predicted category using the SVM model is sport.
# The conditional probability is: 79.84152894508706
# 7069 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7070 The predicted category using the SVM model is sport.
# The conditional probability is: 63.90308673175584
# 7071 The predicted category using the SVM model is business.
# The conditional probability is: 40.89308937661709
# 7072 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7073 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7074 The predicted category using the SVM model is sport.
# The conditional probability is: 37.86659674204891
# 7075 The predicted category using the SVM model is sport.
# The conditional probability is: 42.74206642647195
# 7076 The predicted category using the SVM model is politics.
# The conditional probability is: 46.15353139021374
# 7077 The predicted category using the SVM model is business.
# The conditional probability is: 39.670112378400425
# 7078 The predicted category using the SVM model is business.
# The conditional probability is: 68.08183627814043

# %%
X_test[132]
# Out:
# 'elections matter    power  protect  family’ health care make  plan grab  friends  vote https//tco/ry8ip1km9p'

# %%
texts[132]
# Out:
# 'Elections matter. You have the power to protect a family’s health care. Make a plan, grab some friends, and vote: https://t.co/rY8Ip1km9p'
